# %%
include("/home/juancagc/.julia/dev/BertiniReal/src/decomposition.jl")
using .decompositionModule
include("/home/juancagc/.julia/dev/BertiniReal/src/parser.jl")
using .parserModule
include("/home/juancagc/.julia/dev/BertiniReal/src/data.jl")
using .dataModule
include("/home/juancagc/.julia/dev/BertiniReal/src/vertex.jl")
using .vertexModule

include("/home/juancagc/.julia/dev/BertiniReal/src/plotbr.jl")
using .plotbrModule
path = "/home/juancagc/.julia/dev/BertiniReal/pruebas/astroid/Dir_Name"
directory, MPtype, dimension = parse_directory_name(path)
# Out:
# 3-element Vector{String}:
#  "/home/juancagc/.julia/dev/BertiniReal/pruebas/astroid/./output_dim_1_comp_0"
#  "2"
#  "1"

# %%
cur = Curve(directory)
# Out:
# No samples to gather
# ...

# %%
Curve
# Out:
# Curve

# %%
display(Curve)
# Out:
# Curve

# %%
display(cur)
# Out:
# Curve(Main.plotbrModule.curveModule.decompositionModule.Decomposition("/home/juancagc/.julia/dev/BertiniReal/pruebas/astroid/./output_dim_1_comp_0", false, nothing, "CONFIG\ntracktype: 1;\nimagthreshold: 1e-5;\nEND;\nINPUT\nvariable_group X1,X2;\nfunction f1;\nf1=(X1^2+X2^2-1)^3+27*X1^2*X2^2;\nEND;\n\n", "input_dim_1_comp_0_deflated", 2, Any[[-0.1255937856276809, 0.0], [-0.9920817511736159, 0.0]], 1, Any[Any[0.2607313554905494 + 0.524031775337298im, -0.5525279258828397 - 0.022968834097052904im, -0.5873392161002912 + 0.08141147162056024im]], 2.000000000000043, 0, [0.0, 0.0], 1, Dict{String, Any}(), Any[Vertex(Any[4.7072381416398205e-17 + 4.229541494318076e-17im, -0.9999999999999974 - 7.861921416977843e-15im], 0, 513), Vertex(Any[-1.0 + 8.848411955874337e-15im, 2.1976139116088976e-17 + 6.778733465912847e-17im], 0, 513), Vertex(Any[-7.703479257425334e-17 + 1.5944567636692286e-16im, 1.0000000000000273 + 1.969478706327943e-14im], 0, 513), Vertex(Any[-0.9764328530506518 - 4.448671137363834
# ...

# %%
plotbr(cur)
# Out:
# ┌ Warning: Skipped marker arg triangle.
# └ @ Plots /home/juancagc/.julia/packages/Plots/ju9dp/src/args.jl:1149
